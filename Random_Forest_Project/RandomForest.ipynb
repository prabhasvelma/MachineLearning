# %%
import pandas as pd
from sklearn import datasets

# %%
x=datasets.load_iris()

# %%
x.keys()
# Out:
# dict_keys(['data', 'target', 'frame', 'target_names', 'DESCR', 'feature_names', 'filename', 'data_module'])

# %%
df=pd.DataFrame(x.data)
df
# Out:
#        0    1    2    3
# 0    5.1  3.5  1.4  0.2
# 1    4.9  3.0  1.4  0.2
# 2    4.7  3.2  1.3  0.2
# 3    4.6  3.1  1.5  0.2
# 4    5.0  3.6  1.4  0.2
# ..   ...  ...  ...  ...
# 145  6.7  3.0  5.2  2.3
# 146  6.3  2.5  5.0  1.9
# 147  6.5  3.0  5.2  2.0
# 148  6.2  3.4  5.4  2.3
# 149  5.9  3.0  5.1  1.8
#
# [150 rows x 4 columns]

# %%
df['target']=x.target
df
# Out:
#        0    1    2    3  target
# 0    5.1  3.5  1.4  0.2       0
# 1    4.9  3.0  1.4  0.2       0
# 2    4.7  3.2  1.3  0.2       0
# 3    4.6  3.1  1.5  0.2       0
# 4    5.0  3.6  1.4  0.2       0
# ..   ...  ...  ...  ...     ...
# 145  6.7  3.0  5.2  2.3       2
# 146  6.3  2.5  5.0  1.9       2
# 147  6.5  3.0  5.2  2.0       2
# 148  6.2  3.4  5.4  2.3       2
# 149  5.9  3.0  5.1  1.8       2
#
# [150 rows x 5 columns]

# %%
x.target_names
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype='<U10')

# %%
df['target_name']=df.target.apply(lambda val:x.target_names[val])
df
# Out:
#        0    1    2    3  target target_name
# 0    5.1  3.5  1.4  0.2       0      setosa
# 1    4.9  3.0  1.4  0.2       0      setosa
# 2    4.7  3.2  1.3  0.2       0      setosa
# 3    4.6  3.1  1.5  0.2       0      setosa
# 4    5.0  3.6  1.4  0.2       0      setosa
# ..   ...  ...  ...  ...     ...         ...
# 145  6.7  3.0  5.2  2.3       2   virginica
# 146  6.3  2.5  5.0  1.9       2   virginica
# 147  6.5  3.0  5.2  2.0       2   virginica
# 148  6.2  3.4  5.4  2.3       2   virginica
# 149  5.9  3.0  5.1  1.8       2   virginica
#
# [150 rows x 6 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
sample=df.drop('target_name',axis='columns')
sample
# Out:
#        0    1    2    3  target
# 0    5.1  3.5  1.4  0.2       0
# 1    4.9  3.0  1.4  0.2       0
# 2    4.7  3.2  1.3  0.2       0
# 3    4.6  3.1  1.5  0.2       0
# 4    5.0  3.6  1.4  0.2       0
# ..   ...  ...  ...  ...     ...
# 145  6.7  3.0  5.2  2.3       2
# 146  6.3  2.5  5.0  1.9       2
# 147  6.5  3.0  5.2  2.0       2
# 148  6.2  3.4  5.4  2.3       2
# 149  5.9  3.0  5.1  1.8       2
#
# [150 rows x 5 columns]

# %%
x_train,x_test,y_train,y_test=train_test_split(sample.drop('target',axis='columns'),sample.target,test_size=0.2)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
model=RandomForestClassifier(n_estimators=40)

# %%
model.fit(x_train,y_train)
# Out:
# RandomForestClassifier(n_estimators=40)

# %%
model.score(x_test,y_test)
# Out:
# 0.9666666666666667
